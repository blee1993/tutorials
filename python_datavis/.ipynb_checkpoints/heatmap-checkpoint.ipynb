# %%
print("Hello World")
for i in range(1,11):
    print(i)
# Out:
# Hello World

# %%
# Make Data Frame with 100 Samples and 200 Positions with random values between 1 and 10
# Goal is to make a heatmap and export to html

sample_names = []

for i in range(1,101):
    sample_names.append("Sample" + "_" + str(i))

locations = []

for i in range(1,201):
    locations.append("Location" + "_" + str(i))
    
values=[]
for i in range(len(sample_names)):
    sample_vals = []
    for j in range(len(locations)):
        a = (random.uniform(1,10))
        a = (random.random())
        sample_vals.append(a)
    values.append(sample_vals)
    

# Create a dataframe with 0 values
import pandas as pd

df = pd.DataFrame(values,index = sample_names, columns = locations)
df.head() #check 5 lines
# Out:
#           Location_1  Location_2  Location_3  Location_4  Location_5  \
# Sample_1    0.362971    0.053325    0.476319    0.965078    0.254799
# Sample_2    0.202686    0.187897    0.801619    0.186015    0.667649
# Sample_3    0.700034    0.607908    0.746204    0.305521    0.826216
# Sample_4    0.682286    0.001567    0.990079    0.686967    0.438960
# Sample_5    0.172141    0.064163    0.109220    0.244506    0.342753
#
#           Location_6  Location_7  Location_8  Location_9  Location_10  \
# Sample_1    0.926503    0.093356    0.946317    0.350591     0.409736
# Sample_2    0.515529    0.740283    0.598152    0.037448     0.512712
# Sample_3    0.359547    0.180720    0.166860    0.483739     0.705055
# Sample_4    0.136199    0.027689    0.447677    0.236725     0.647084
# Sample_5    0.860874    0.356047    0.921225    0.115503     0.865226
#
#               ...       Location_191  Location_192  Location_193  \
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=go.Heatmap(z=values,x=locations,y=sample_names,hoverongaps = False, colorscale='Viridis'))
fig.show()
# Out:
# <div>
#
#
#             <div id="4a352956-e2bc-4b18-9188-981e8bdabe96" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a352956-e2bc-4b18-9188-981e8bdabe96")) {
#                     Plotly.newPlot(
#                         '4a352956-e2bc-4b18-9188-981e8bdabe96',
# ...

# %%
values
# Out:
# [[9.062974789586791,
#   1.6548528448403168,
#   4.395398245234022,
#   2.1983435716342683,
#   8.974642377115059,
#   4.62281704815448,
#   5.0489597403446265,
#   8.203832364857941,
#   5.828257226323881,
#   1.4680829820458121,
#   2.086629364032101,
#   2.315950319433124,
#   3.1126168034366044,
#   7.7078526104508605,
#   8.481602169226328,
#   6.923075790393685,
#   6.23745879661368,
#   1.0028340570929042,
#   7.6460460969129995,
#   7.6800585993399,
#   5.33046859586609,
#   8.22636278708329,
#   6.248146558674399,
#   7.837623938852091,
#   2.3287088232355737,
#   9.353232731591682,
#   8.328407114928723,
#   6.926749961081189,
#   2.001003697149202,
#   3.408353827048199,
#   2.196624648219734,
#   6.1565427712868095,
#   7.461619830370622,
#   6.928239593419411,
#   6.591259993290922,
#   8.872079023112004,
#   4.8701823856511215,
#   6.703002321579421,
#   4.837941785575577,
#   3.2679257120785588,
#   6.153222460422892,
#   6.3441174611875395,
#   6.622438387121771,
# ...
